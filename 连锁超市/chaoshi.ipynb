# %%
import requests #用於API HTTP requests
import pandas as pd


def amap_api_search_by_keyword_city_code(kw, cc, api_key):

    parameters = {'key': '53969d12c0739b670690c555e79ea712'}  # 高德地图API 获取Key
    parameters.update( {'keywords': kw,
                        'city':     cc,
                        'citylimit': True
                       } )

    pois = []   # 建构最终结果列表pois
    pg_no = 1   # 建构pg_no，每次给不一样的可选参数page值

    while True: # 不断迭代，直到 break跳出
        parameters.update({'page':pg_no})  #建构可选参数page值 为 pg_no

        r = requests.get ("http://restapi.amap.com/v3/place/text", params=parameters)
        data = r.json()

        pois.extend(data['pois'])         # 使用Python列表之extend方法，把返回数据中的结果data['pois']存入pois


        no_pois_this_search = len(pois)   # 计算 累积实质结果数
        no_pois = int(data['count'])      # 计算 应有的实质数量


        if (no_pois_this_search >= no_pois):  # 若 累积实质结果数 >= 应有的实质数量
            break                                   # 则结束迭代跳出
        else:
            pg_no +=1                               # 否则找下一页数据，把 pg_no增1


    # 使用pandas 模块处理数据
    df_input = pd.DataFrame(pois)

    # 选择部份栏位准备输出
    select_fields = "location	address	adname	cityname	id	importance	name	pname	tel	type	typecode".split("\t")
    df = df_input[select_fields]

    # 经纬度 增加新栏位字段
    df = df.assign( 经 = [x.split(',')[0] for x in df['location']])
    df = df.assign( 纬 = [x.split(',')[1] for x in df['location']])
    df = df.assign(keywords = [kw]*len(df['location']))

    
    # 使用 return返回
    return(df)

# %%
 keywords_fields = "沃尔玛	家乐福	人人乐	好又多".split("\t")

# %%
g_list=[]

for y in  keywords_fields:
    z=amap_api_search_by_keyword_city_code(y, '中国', 'ee83ffb0500bcbbe5929a0d58d012e0e')
   
    g_list.append(z)

# %%
df=pd.concat(g_list)

# %%
df
# Out:
#                  location                          address adname cityname  \
# 0    113.870770,23.108626                         石龙汇星商业中心    东莞市      东莞市
# 1    125.117426,46.594662                      经六街与纬五路路交叉口   萨尔图区      大庆市
# 2    113.037875,23.709799                           先锋东路3号    清城区      清远市
# 3    101.553303,25.043112                          团结路169号    楚雄市  楚雄彝族自治州
# 4    106.496457,29.582894               松石大道与柏树堡立交交叉口北150米    渝北区      重庆市
# 5    113.548860,22.231595                迎宾南路2095号珠海摩尔广场B1    香洲区      珠海市
# 6    113.919793,22.539908  南新路3229号(深南大道与南新路交界处鸿州文鼎家园1-2层)    南山区      深圳市
# 7    112.556114,37.818683                 长风街705号和信时尚商城B1层    小店区      太原市
# 8    116.281781,39.900458                   西翠路5号今日商业中心B1层    海淀区      北京市
# 9    116.338669,39.975273            知春路甲48号盈都大厦D座4号楼B1-2层    海淀区      北京市
# 10   118.786692,32.038146                   洪武路88号悦荟广场2-3层    秦淮区      南京市
# 11   104.045247,30.702818               交大路183号凯德广场·金牛2-3层    金牛区      成都市
# 12   117.017853,36.665133                  泉城路339号万达广场2-3层    历下区      济南市
# 13   117.672517,24.510306                南昌路49号凯德广场·漳州2-3层    芗城区      漳州市
